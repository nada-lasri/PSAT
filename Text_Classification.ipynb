# %% [markdown]
# # Extracting articles links from a set of news websites :
# A classification approach
#
#
# # Initialisation
# We will use Python3 with Numpy for linear algebra, Pandas for data processing and CSV files I/O, and scikit-learn for predictions.

# %%
import requests 
import re
from bs4 import BeautifulSoup
import datetime
import urllib
import requests
import lxml.html
import json
import csv
import sys
import requests
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup

# %% [markdown]
# # Reading data
#
# Let's define some functions to read data from the website into a csv file.

# %%
internal_urls = {}

def is_valid(url):
    """
    Checks whether `url` is a valid URL.
    """
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)

def get_all_website_links(url):
    """
    Returns all URLs that is found on `url` in which it belongs to the same website
    """
    # all URLs of `url`
    urls = set()
    # domain name of the URL without the protocol
    domain_name = urlparse(url).netloc
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    for a_tag in soup.findAll("a"):
        href = a_tag.attrs.get("href")
        if href == "" or href is None:
            continue
        href = urljoin(url, href)
        parsed_href = urlparse(href)
        href = parsed_href.scheme + "://" + parsed_href.netloc + parsed_href.path
        
        if not is_valid(href):
        # not a valid URL
            continue
            
        if href in internal_urls:
            # already in the set
            continue
        
        if domain_name not in href:
            # external link
            continue
            
        urls.add(href)
        title = a_tag.getText().strip().lstrip()       
        title = title.replace(';','')
        title = title.replace('""','')
        title = title.replace("\n", "")
        title = title.replace("\t", "")
        if title == "" or title is None:
            continue
        internal_urls[title] = href
        print(title + ";" + href + ";")

    return internal_urls

def write_in_csv(url_dict):
    with open('training_2.csv', mode='a', encoding="utf-8", newline='') as employee_file:
        employee_writer = csv.writer(employee_file, delimiter=';')

        for url in url_dict:
            employee_writer.writerow([url, url_dict[url]])

# %%
#just a little bit of testing code
# f = open("training_2.csv", "w")
# f.truncate()
# f.close()

# write_in_csv(get_all_website_links(""))

# %% [markdown]
# # Building the training data
#
# The training.csv file has been built by hand in the following manner : given a set of websites, we have extracted all links from that websites and the text associated with each link, using the methods above. One by one, each couple {title, link} has been given the label 0 or 1, 0 if we decide it's not a relevant headline, 1 if it is.
# We used headlines and links from around 5 websites, giving us 537 rows for our training set. It is not much, but I will add a lot more later to make the model more accurate.
#
# The training data looks like this :

# %% [raw]
# Continue reading the main story;https://www.nytimes.com;0
# Skip to content;https://www.nytimes.com;0
# Skip to site index;https://www.nytimes.com;0
# U.S.;https://www.nytimes.com/section/us;0
# International;https://www.nytimes.com/international/;0
# Canada;https://www.nytimes.com/ca/;0
# Español;https://www.nytimes.com/es/;0
# Today’s Paper;https://www.nytimes.com/section/todayspaper;0
# World;https://www.nytimes.com/section/world;0
# Politics;https://www.nytimes.com/section/politics;0
# N.Y.;https://www.nytimes.com/section/nyregion;0
# Business;https://www.nytimes.com/section/business;0
# Opinion;https://www.nytimes.com/section/opinion;0
# Tech;https://www.nytimes.com/section/technology;0

# %% [markdown]
# # Training our classifier
#
# Using the training.csv file we built earlier, we use
# Multinomial NB

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
import pandas as pd

df=pd.read_csv('training.csv', sep=';',header=None)

df = df.replace('\n','', regex=True) 
df = df.fillna(0)
title_columns_data = df.iloc[:, 0]
classification_columns_data = df.iloc[:, 2]

title_columns_data = df.iloc[:, 0]
title_columns_data = title_columns_data.astype(str)

count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(title_columns_data)
X_train_counts.shape

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape

clf = MultinomialNB().fit(X_train_tfidf, classification_columns_data)

# %% [markdown]
# Let's test our classifier with some sentences, for exemple a headline and an unrelated link title :

# %%
docs_new = ['Why Are Election Results Taking So Long? State-by-State Look at Electoral Votes', 'Subscriber Agreement & Terms of Use']
X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_tfidf)

print (docs_new[0], " - prediction : ", predicted[0])
print (docs_new[1], " - prediction : ", predicted[1])
# Out:
# Why Are Election Results Taking So Long? State-by-State Look at Electoral Votes  - prediction :  1.0
# Subscriber Agreement & Terms of Use  - prediction :  0.0

# %% [markdown]
# # Building a pipeline

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
text_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', SGDClassifier(loss='hinge', penalty='l2',
                          alpha=1e-3, random_state=42,
                          max_iter=5, tol=None)),
])

text_clf.fit(title_columns_data, classification_columns_data)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  SGDClassifier(alpha=0.001, max_iter=5, random_state=42,
#                                tol=None))])

# %% [markdown]
# # Testing our classifier
#
# We created a testing file (testing.csv) to see if our classifier is able to predict if a title is a headline or not. We generated the links from the website (here the Economist), and we annoted by hand the 0 or 1 distinction. Let's see how well our classifier fares :

# %%
from sklearn.metrics import f1_score

df_t=pd.read_csv('testing.csv', sep=';',header=None)

df_t = df_t.replace('\n','', regex=True) 
df_t = df_t.fillna(0)
title_columns_data_testing = df_t.iloc[:, 0]
classification_columns_data_testing = df_t.iloc[:, 2]

predicted = text_clf.predict(title_columns_data_testing)

print(f1_score(predicted, classification_columns_data_testing,  average='micro'))
# Out:
# 0.7792207792207793

# %% [markdown]
# We can see that we get a score of 0.78, which is pretty good but could be better. We can use () to make it more precise.

# %% [markdown]
# # Generating a useful list of headline-links
#
# Using our classifier, we can input a website and get as the output the list of {headline-links} our classifier has deemed acceptable (meaning those with a label of "1"). Here we're using the news.sky websites as an exemple :

# %%
input = "https://news.sky.com/"

pair_dict = get_all_website_links(input)
dict_df = pd.DataFrame(list(pair_dict.items()),columns=['title', 'link'])

title_columns = dict_df.iloc[:, 0]
predicted = text_clf.predict(title_columns)
dict_df['prediction'] = predicted 

# selecting rows based on condition 
rslt_df = dict_df[dict_df['prediction'] == 1.0] 

rslt_df = rslt_df.drop(['prediction'], axis=1)
rslt_df
# Out:
#                                                  title  \
# 1                                           Watch Live
# 14                                            Analysis
# 17                                             Weather
# 19   Biden closes in on Trump in next battleground ...
# 20   Trump supporters - some armed with rifles - ga...
# 21   Which states haven't declared a winner yet - a...
# 22   If Biden wins Arizona and Georgia, history wil...
# 23   Sainsbury's warns 3,500 jobs could go in super...
# 24   'Reckless' rave organiser fined £10,000 after ...
# 25   Bank of England unleashes £150bn of new QE as ...
# 26   Reluctant resignation: England begins second l...
# 27   This time, Captain Sir Tom Moore wants YOU to ...
# 29   What you can and can't do in second England lo...
# 30   Liverpool to get mass COVID-19 testing  - here...
# 31   Can I go on holiday and will I get a refund if...
# 32   What are the restrictions in your area? Find o...
# 33   'We're facing a war': Italy's frontline doctor...
# 34   Here's how Wales defines the 'essential items'...
# 35   Some people are suffering lasting damage from ...
# 36   Can my baby sitter come over? Can I book my cl...
# 37   Circuit breaker lockdown: What is the science ...
# 38   Which tier are you in? Full list of coronaviru...
# 39   The financial aid packages for virus-hit busin...
# 40   Are cases rising or falling in current and pos...
# 41   London moves to Tier 2 - but how bad is COVID ...
# 42   Why has the North been hit harder by coronavir...
# 43   The number of coronavirus cases and deaths whe...
# 44   Win or lose, Trump still has millions more vot...
# 45   Unrest, delays and threats - the 'dicey' fight...
# 46   Exit polls reveal how Americans voted - and th...
# 47   Trump prepares to fight election results in co...
# 48   Once again, pollsters have got egg on their fa...
# 49   Early voters and elderly candidates: The recor...
# 50   First transgender state senator among the pers...
# 51   There's no conspiracy - we have just seen 'red...
# 52   Mini red wave in Florida as many Cuban America...
# 53   How the US election is being won - in charts a...
# 54   'Stop the count!' - Tension as 'poll watchers'...
# 55            'Go home!': Police break up illegal rave
# 56           Police disperse Londoners in new lockdown
# 57     Five things you may have missed in the election
# 59   The race for a vaccine is edging towards the f...
# 60                                          Paul Kelso
# 61   PM says sorry to businesses for 'frustration a...
# 63   Johnny Depp's reputation lies in tatters - his...
# 64   In 1968, Sislin Fay Allen became the UK's firs...
# 65   I am both proudly British and proudly West Afr...
# 66   My son isn't treated equally in the eyes of th...
# 67   I help other families grieve for their babies ...
# 68   Nurse arrested for trying to take mother with ...
# 69   Businesses back 'Red Wall' Tories call for pos...
# 70   Pre-historic remains prompt a re-think of theo...
# 71   All secondary school pupils must wear face mas...
# 73                  Daughter detained in care home row
# 74            80-year-old radio masts demolished in US
# 75                   'Biden could have voted 50 times'
# 76          Fatal flooding and landslides hit Honduras
# 77       'Poll watchers' protest outside Detroit count
# 78       Unit 74455: Russian hackers wanted by the FBI
# 79                       US election too early to call
# 80            What happened on US election night 2020?
# 82   NHS England to move to highest alert level fro...
# 83   What Biden and Trump need to do to win the US ...
# 84   'Small chance' COVID jab will be ready before ...
# 85   The key states needed to win the White House race
# 86   First arrests made over alleged fraud linked t...
# 87   Revealed: Which shops can stay open during loc...
# 88   When will we know the US election result - and...
# 89                                            About Us
# 97                             Sky News For Your Phone
# 101  Minister says lockdown extension in England 'c...
# 102  Trump supporter: 'All over the country it's no...
#
#                                                   link
# 1                      https://news.sky.com/watch-live
# 14                       https://news.sky.com/analysis
# 17                        https://news.sky.com/weather
# 19   https://news.sky.com/story/us-election-joe-bid...
# 20   https://news.sky.com/story/us-election-2020-li...
# 21   https://news.sky.com/story/us-election-2020-se...
# 22   https://news.sky.com/story/us-election-2020-if...
# 23   https://news.sky.com/story/sainsburys-reveals-...
# 24   https://news.sky.com/story/coronavirus-reckles...
# 25   https://news.sky.com/story/coronavirus-bank-of...
# 26   https://news.sky.com/story/reluctant-resignati...
# 27   https://news.sky.com/story/coronavirus-lets-tr...
# 29   https://news.sky.com/story/coronavirus-what-yo...
# 30   https://news.sky.com/story/coronavirus-what-ar...
# 31   https://news.sky.com/story/coronavirus-travel-...
# 32   https://news.sky.com/story/coronavirus-what-ar...
# 33   https://news.sky.com/story/coronavirus-were-fa...
# 34   https://news.sky.com/story/coronavirus-what-ar...
# 35   https://news.sky.com/story/long-covid-the-debi...
# 36   https://news.sky.com/story/coronavirus-what-yo...
# 37   https://news.sky.com/story/circuit-breaker-loc...
# 38   https://news.sky.com/story/how-does-the-three-...
# 39   https://news.sky.com/story/coronavirus-the-fin...
# 40   https://news.sky.com/story/coronavirus-are-cas...
# 41   https://news.sky.com/story/london-restrictions...
# 42   https://news.sky.com/story/coronavirus-why-has...
# 43   https://news.sky.com/story/coronavirus-in-the-...
# 44   https://news.sky.com/story/us-election-2020-wi...
# 45   https://news.sky.com/story/us-election-2020-un...
# 46   https://news.sky.com/story/us-election-2020-ex...
# 47   https://news.sky.com/story/us-election-2020-wh...
# 48   https://news.sky.com/story/us-election-2020-on...
# 49   https://news.sky.com/story/early-voters-and-el...
# 50   https://news.sky.com/story/us-election-2020-tr...
# 51   https://news.sky.com/story/us-election-2020-th...
# 52   https://news.sky.com/story/us-election-2020-mi...
# 53   https://news.sky.com/story/how-the-us-election...
# 54   https://news.sky.com/story/us-election-2020-di...
# 55   https://news.sky.com/video/square-video-2-rave...
# 56   https://news.sky.com/video/coronavirus-police-...
# 57   https://news.sky.com/video/five-things-you-may...
# 59   https://news.sky.com/story/coronavirus-the-rac...
# 60          https://news.sky.com/author/paul-kelso-534
# 61   https://news.sky.com/story/coronavirus-pm-says...
# 63   https://news.sky.com/story/johnny-depp-what-do...
# 64   https://news.sky.com/story/black-history-month...
# 65   https://news.sky.com/story/i-am-both-proudly-b...
# 66   https://news.sky.com/story/mother-of-toddler-w...
# 67   https://news.sky.com/story/baby-loss-awareness...
# 68   https://news.sky.com/story/coronavirus-nurse-a...
# 69   https://news.sky.com/story/coronavirus-busines...
# 70   https://news.sky.com/story/pre-historic-remain...
# 71   https://news.sky.com/story/coronavirus-older-c...
# 73   https://news.sky.com/video/coronavirus-woman-a...
# 74   https://news.sky.com/video/square-video-radio-...
# 75   https://news.sky.com/video/us-election-2020-ru...
# 76   https://news.sky.com/video/square-video-hondur...
# 77   https://news.sky.com/video/us-election-2020-tr...
# 78   https://news.sky.com/story/unit-74455-russian-...
# 79   https://news.sky.com/story/too-early-to-call-1...
# 80   https://news.sky.com/story/what-happened-on-us...
# 82   https://news.sky.com/story/coronavirus-nhs-eng...
# 83   https://news.sky.com/story/us-election-2020-wh...
# 84   https://news.sky.com/story/coronavirus-small-c...
# 85   https://news.sky.com/video/the-key-states-need...
# 86   https://news.sky.com/story/coronavirus-first-a...
# 87   https://news.sky.com/story/coronavirus-shops-a...
# 88   https://news.sky.com/story/us-election-2020-yo...
# 89    https://news.sky.com/info/policies-and-standards
# 97               https://news.sky.com/info/smartphones
# 101  https://news.sky.com/story/coronavirus-lockdow...
# 102  https://news.sky.com/video/trump-supporter-at-...

# %%
print ("Initial number of links : ",dict_df.shape[0])
print("Resulting number of links : ",rslt_df.shape[0])
# Out:
# Initial number of links :  103
# Resulting number of links :  72

# %% [markdown]
# As we can see, the intial set had 103 {headline-link} rows, and thanks to the classification algorithm, we only have 72 left. I would say that among those 72, around 5 or 6 are not really useful links ("About Us", "Sky News For Your Phone"...), but this is because our model is not really optimal, we don't have a lot of training data (only 537 {headline, link} pairs). We need to add more rows to the training set (not really difficult to do, just a bit time consuming), and improve the classification on the text in the headlines.
